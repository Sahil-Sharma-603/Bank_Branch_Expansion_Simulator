# %% [markdown]
# # Bank Branch Expansion Simulator
# ## Exploratory Data Analysis — FDIC Summary of Deposits
#
# This notebook walks through the full EDA pipeline for the project:
#
# 1. Load and inspect the raw SOD data
# 2. Clean and validate
# 3. Analyse deposit distributions
# 4. Explore branch density by state and ZIP
# 5. Compute the Opportunity Score and Expected Capture
# 6. Identify top expansion targets
# 7. Export processed CSVs for Tableau
#
# **Before running:** Update `DATA_PATH` in Cell 2 to point to your downloaded SOD CSV.

# %%
# ── Imports ────────────────────────────────────────────────────────────────
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
from pathlib import Path

pd.set_option('display.float_format', '{:,.2f}'.format)
pd.set_option('display.max_columns', 30)

# %%
# ── Configuration ──────────────────────────────────────────────────────────
# Update this path to point to your downloaded FDIC SOD CSV file.

ROOT = Path('/Users/Sahil/Documents/Data Analytic Project/Data Analytics Project by Harsh/Project 2 Bank Branch Expansion')
DATA_PATH = ROOT/'SOD_CustomDownload_2025_06_30.csv'
OUTPUT_DIR = ROOT/'data'/'processed'
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

print(f"Data path : {DATA_PATH}")
print(f"Output dir : {OUTPUT_DIR}")



# For multi-year analysis, pass a list: [PATH_2022, PATH_2023]
# Out:
# Data path : /Users/Sahil/Documents/Data Analytic Project/Data Analytics Project by Harsh/Project 2 Bank Branch Expansion/SOD_CustomDownload_2025_06_30.csv
# Output dir : /Users/Sahil/Documents/Data Analytic Project/Data Analytics Project by Harsh/Project 2 Bank Branch Expansion/data/processed

# %% [markdown]
# ---
# ## 1. Load and Inspect Raw Data

# %%
df = pd.read_csv(DATA_PATH)
print(f'Shape:{df.shape}') # Rows are the unqiue branches 
df.head()
# Out:
# Shape:(76097, 12)
#    YEAR  CERT                             NAMEFULL  \
# 0  2025    14  State Street Bank and Trust Company
# 1  2025    14  State Street Bank and Trust Company
# 2  2025    14  State Street Bank and Trust Company
# 3  2025    35                           AuburnBank
# 4  2025    35                           AuburnBank
#
#                           ADDRESBR  BRNUM  UNINUMBR STALPBR STALP   DEPSUMBR  \
# 0     One Congress Street, Suite 1      0         6      MA    MA  207849000
# 1    2323 Grand Boulevard, Floor 5     33    667916      MO    MA          0
# 2  111 Town Square Place,suite 735     34    671182      NJ    MA          0
# 3                     100 N Gay St      0        17      AL    AL     553080
# 4                1851 Frederick Rd     10    478897      AL    AL      60269
#
#    SIMS_LATITUDE  SIMS_LONGITUDE  ZIPBR
# 0          42.36          -71.06   2114
# 1          39.09          -94.58  64108
# 2          40.73          -74.03   7310
# 3          32.61          -85.48  36830
# 4          32.62          -85.40  36801

# %%
# Renaming Columns
df = df.rename(columns = {
        'DEPSUMBR':'DEPOSITS_USD',
        'SIMS_LATITUDE':'LAT',
        'SIMS_LONGITUDE':'LON',
        'STALPBR':'STATE',
        'ZIPBR':'ZIP',
        'NAMEFULL':'BANK_NAME',
        'ADDRESBR':'ADDRESS'
     
})

print(f'Shape:{df.shape}')
df.head()
# Out:
# Shape:(76097, 12)
#    YEAR  CERT                            BANK_NAME  \
# 0  2025    14  State Street Bank and Trust Company
# 1  2025    14  State Street Bank and Trust Company
# 2  2025    14  State Street Bank and Trust Company
# 3  2025    35                           AuburnBank
# 4  2025    35                           AuburnBank
#
#                            ADDRESS  BRNUM  UNINUMBR STATE STALP  DEPOSITS_USD  \
# 0     One Congress Street, Suite 1      0         6    MA    MA     207849000
# 1    2323 Grand Boulevard, Floor 5     33    667916    MO    MA             0
# 2  111 Town Square Place,suite 735     34    671182    NJ    MA             0
# 3                     100 N Gay St      0        17    AL    AL        553080
# 4                1851 Frederick Rd     10    478897    AL    AL         60269
#
#     LAT    LON    ZIP
# 0 42.36 -71.06   2114
# 1 39.09 -94.58  64108
# 2 40.73 -74.03   7310
# 3 32.61 -85.48  36830
# 4 32.62 -85.40  36801

# %%
# Missing Value Summary

missing = df.isnull().sum()
missing_percentage = (missing/len(df)) * 100
missing_df = pd.DataFrame({
             'Missing Count': missing,
              'Missing %': missing_percentage
})

missing_df[missing_df['Missing Count']>0]
# Out:
# Empty DataFrame
# Columns: [Missing Count, Missing %]
# Index: []

# %%
# Data Fixes ----------------

# 1. Remove branches with 0 deposits
df = df[df['DEPOSITS_USD'] > 0].copy()

# 2. Ensure ZIP codes are 5 digit strings (pad with 0s if needed)
df['ZIP'] = df['ZIP'].astype(str).str.zfill(5)


# 3. Optional: Remove rows with missing lang/lon (if needed for mapping)
df = df.dropna(subset = ['LAT','LON'])

# 4. Optional: Reset the Index
df.reset_index(drop=True, inplace=True)

#5. Change Deposits to Actual $$ (from 1000s)
df['DEPOSITS_USD'] = df['DEPOSITS_USD']*1000


print(f'After Cleaning:{len(df):,} branches remanin')
# Out:
# After Cleaning:73,868 branches remanin

# %%
df.head(10)
# Out:
#    YEAR  CERT                            BANK_NAME  \
# 0  2025    14  State Street Bank and Trust Company
# 1  2025    35                           AuburnBank
# 2  2025    35                           AuburnBank
# 3  2025    35                           AuburnBank
# 4  2025    35                           AuburnBank
# 5  2025    35                           AuburnBank
# 6  2025    35                           AuburnBank
# 7  2025    35                           AuburnBank
# 8  2025    39            Robertson Banking Company
# 9  2025    39            Robertson Banking Company
#
#                         ADDRESS  BRNUM  UNINUMBR STATE STALP  DEPOSITS_USD  \
# 0  One Congress Street, Suite 1      0         6    MA    MA  207849000000
# 1                  100 N Gay St      0        17    AL    AL     553080000
# 2             1851 Frederick Rd     10    478897    AL    AL      60269000
# 3            2315 Bent Creek Rd     12    493224    AL    AL      94392000
# 4              132 Fob James Dr     13    531906    AL    AL      54872000
# 5                  215 S 6th St      3    180886    AL    AL     107955000
# 6             1351 S Donahue Dr      7    361391    AL    AL      52561000
# 7                 950 Auburn Rd      8    364622    AL    AL      17566000
# 8              216 N Walnut Ave      0        21    AL    AL     233726000
# 9          1406 Us Highway 80 W      2    180895    AL    AL      32681000
#
#     LAT    LON    ZIP
# 0 42.36 -71.06  02114
# 1 32.61 -85.48  36830
# 2 32.62 -85.40  36801
# 3 32.61 -85.43  36830
# 4 32.82 -85.18  36854
# 5 32.65 -85.38  36801
# 6 32.58 -85.49  36832
# 7 32.57 -85.66  36866
# 8 32.52 -87.84  36732
# 9 32.50 -87.85  36732

# %% [markdown]
# ---
# ## 2. Summary Statistics

# %%
print('=== Dataset Summary ===')
print(f'Total Branches: {len(df):,}')
print(f'Unique Banks: {df['BANK_NAME'].nunique():,}')
print(f'Unique ZIPs: {df['ZIP'].nunique():,}')
print(f'States Covered: {df['STATE'].nunique():,}')
print(f'Total Deposits: ${df['DEPOSITS_USD'].astype(int).sum():,.0f}')
print(f'Average Deposits per Branch: ${df['DEPOSITS_USD'].astype(int).mean():,.0f}')
print(f'Median Deposits per Branch: ${df['DEPOSITS_USD'].astype(int).median():,.0f}')
# Out:
# === Dataset Summary ===
# Total Branches: 73,868
# Unique Banks: 3,893
# Unique ZIPs: 17,968
# States Covered: 58
# Total Deposits: $18,103,110,848,000
# Average Deposits per Branch: $245,073,792
# Median Deposits per Branch: $82,056,500

# %% [markdown]
# ---
# ## 3. Deposit Distribution Analysis

# %%
# Deposit per branch — exclude top 1% to remove outlier skew
dep_m = df['DEPOSITS_USD'] / 1e6
p99 = dep_m.quantile(0.99) # remove the top 1%

# Plot histogram
fig = px.histogram(dep_m[dep_m < p99], 
                   nbins = 100, 
                   title = 'Deposits per branch (up to 99th percentile)',
                   labels = {'value': 'Deposits ($M)'},
                   color_discrete_sequence = ['#2563EB']
                  )

fig.update_layout(bargap=0.05, showlegend=False)
fig.show()

# Print Summary

print(f'Branches < $1M deposits : {(dep_m < 1).sum():,} ({(dep_m < 1).mean() * 100:.1f}%) ')
print(f'Branches $1M - $100M deposits : {((dep_m >= 1 ) & (dep_m < 100)).sum():,} ')
print(f'Branches > $100M deposits : {(dep_m >= 100).sum():,} ')
# Out:
# Branches < $1M deposits : 398 (0.5%)
# Branches $1M - $100M deposits : 42,650
# Branches > $100M deposits : 30,820

# %% [markdown]
# ---
# ## 4. State-Level Analysis

# %%
# Group Data at State Level

state_df = (
    df.groupby('STATE', as_index = False)
    .agg(
        TOTAL_DEPOSITS = ('DEPOSITS_USD', 'sum'),
        BRANCH_COUNT = ('CERT','count'),
        ZIP_COUNT = ('ZIP', 'nunique')
    )
)

state_df['AVG_DEPOSIT_PER_BRANCH'] = state_df['TOTAL_DEPOSITS'] / state_df['BRANCH_COUNT']
state_df = state_df.sort_values('TOTAL_DEPOSITS', ascending=False)

# %%
fig = px.bar(
    state_df.head(20),
    x='TOTAL_DEPOSITS', y='STATE',
    orientation = 'h',
    title = 'Top 20 States by Total Deposits',
    labels = {'TOTAL_DEPOSITS':'Total Deposits ($)','STATE':'State'},
    color = 'TOTAL_DEPOSITS', color_continuous_scale = 'Blues'
)

fig.update_layout(yaxis=dict(autorange='reversed'),coloraxis_showscale=False, showlegend=False)
fig.show()

# %%
# Branch count by state

fig = px.bar(
    state_df.head(20),
    x='BRANCH_COUNT', y='STATE',
    orientation = 'h',
    title = 'Top 20 States by Branch Count',
    labels = {'BRANCH_COUNT':'Number of Branches','STATE':'State'},
    color = 'BRANCH_COUNT', color_continuous_scale = 'Greens'
)

fig.update_layout(yaxis=dict(autorange='reversed'),coloraxis_showscale=False, showlegend=False)
fig.show()

# %% [markdown]
# ---
# ## 5. ZIP-Level Analysis

# %%
# Aggregate branch level data to ZIP level

zip_df = (
    df.groupby('ZIP', as_index = False)
    .agg(
        STATE = ('STATE','first'),
        TOTAL_DEPOSITS = ('DEPOSITS_USD', 'sum'),
        BRANCH_COUNT = ('CERT','count'),
        ZIP_COUNT = ('ZIP', 'nunique'),
        LAT = ('LAT','mean'),
        LON = ('LON','mean')
    )
)

zip_df['AVG_DEPOSIT_PER_BRANCH'] = zip_df['TOTAL_DEPOSITS'] / zip_df['BRANCH_COUNT']
print(f'Total ZIPs in the dataset: {len(zip_df):,}')
zip_df.head()
# Out:
# Total ZIPs in the dataset: 17,968
#      ZIP STATE  TOTAL_DEPOSITS  BRANCH_COUNT  ZIP_COUNT   LAT    LON  \
# 0  00601    PR        63000000             1          1 18.16 -66.72
# 1  00602    PR       302762000             2          1 18.36 -67.17
# 2  00603    PR       599215000             4          1 18.45 -67.13
# 3  00604    PR       202000000             1          1 18.42 -67.15
# 4  00606    PR        17000000             1          1 18.17 -66.94
#
#    AVG_DEPOSIT_PER_BRANCH
# 0           63,000,000.00
# 1          151,381,000.00
# 2          149,803,750.00
# 3          202,000,000.00
# 4           17,000,000.00

# %%
# Branches per ZIP distribution

# Plot histogram
fig = px.histogram(
    zip_df['BRANCH_COUNT'],
    nbins = 50, 
    title = 'Distribution of Branch Count per ZIP',
    labels = {'value': 'Branches per ZIP'},
    color_discrete_sequence = ['#059669']
)

fig.update_layout(bargap=0.05, showlegend=False)
fig.show()

# Print Summary

print(f'ZIPs with 1 branch : {(zip_df['BRANCH_COUNT'] == 1).sum():,} ')
print(f'ZIPs with 2-5 branch : {zip_df['BRANCH_COUNT'].between(2,5).sum():,} ')
print(f'ZIPs with 6+ branch : {(zip_df['BRANCH_COUNT'] >= 6).sum():,} ')
# Out:
# ZIPs with 1 branch : 6,269
# ZIPs with 2-5 branch : 7,195
# ZIPs with 6+ branch : 4,504

# %% [markdown]
# ---
# ## 6. Pareto Analysis — Deposit Concentration

# %%
# create sorted dataframe
zip_sorted = zip_df.sort_values('TOTAL_DEPOSITS', ascending=False).reset_index(drop=True)
# calcuating cumulative sum
zip_sorted['CUM_SHARE'] = zip_sorted['TOTAL_DEPOSITS'].cumsum() / zip_sorted['TOTAL_DEPOSITS'].sum()*100
zip_sorted['ZIP_RANK_PCT'] = (zip_sorted.index+1) / len(zip_sorted) * 100

# Find the 80/20 point
idx_80 = (zip_sorted['CUM_SHARE'] >= 80).idxmax()
pct_zip_for_80_pct = zip_sorted.loc[idx_80, 'ZIP_RANK_PCT']
print(f'Top {pct_zip_for_80_pct:.1f}% of ZIPS hold 80% of total deposits')
# Out:
# Top 16.0% of ZIPS hold 80% of total deposits

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(
    x = zip_sorted['ZIP_RANK_PCT'],
    y= zip_sorted['CUM_SHARE'],
    mode = 'lines',
    line = dict(color = '#2563EB', width=2),
    name = 'Cumulative deposit share'
    
))

fig.update_layout(
    title='Pareto: Cumulative Deposit Share by ZIP Percentile',
    xaxis_title='ZIP Code Perecentile (sorted by deposits)',
    yaxis_title='Cumulative Share of All Deposits (%)'
)

fig.add_hline(y=80, line_dash='dash', line_color='#EF4444', annotation_text='80% of all deposits')

fig.show()

# %% [markdown]
# ---
# ## 7. Opportunity Score Analysis

# %%
# Normalization

nat_avg_deposits = zip_df['TOTAL_DEPOSITS'].mean()
nat_avg_desity =  zip_df['BRANCH_COUNT'].mean()

zip_df['NORM_DEPOSIT_BASE'] =  zip_df['TOTAL_DEPOSITS'] / nat_avg_deposits
zip_df['NORM_BRANCH_DENSITY'] =  zip_df['BRANCH_COUNT'] / nat_avg_desity 

OPPORTUNITY_WEIGHT_DEPOSIT = 0.6
OPPORTUNITY_WEIGHT_DENSITY = 0.4
CAPTURE_MULTIPLER = 0.02
CAPTURE_PCT_MIN = 0.01
CAPTURE_PCT_MAX = 0.10

zip_df['OPPORTUNITY_SCORE'] = OPPORTUNITY_WEIGHT_DEPOSIT*zip_df['NORM_DEPOSIT_BASE'] - OPPORTUNITY_WEIGHT_DENSITY*zip_df['NORM_BRANCH_DENSITY']


zip_df['CAPTURE_PCT'] = (CAPTURE_MULTIPLER * zip_df['OPPORTUNITY_SCORE']).clip(CAPTURE_PCT_MIN, CAPTURE_PCT_MAX)

zip_df['EXPECTED_CAPTURE_USD'] =  zip_df['TOTAL_DEPOSITS'] * zip_df['CAPTURE_PCT']



zip_df = zip_df.sort_values('OPPORTUNITY_SCORE', ascending=False)
zip_df.head()
# Out:
#          ZIP STATE  TOTAL_DEPOSITS  BRANCH_COUNT  ZIP_COUNT   LAT     LON  \
# 1523   10017    NY    744591256000            20          1 40.75  -73.98
# 10569  57108    SD    531388675000            31          1 43.49  -96.75
# 15861  84111    UT    485479315000            22          1 40.76 -111.89
# 4361   28202    NC    397796853000            10          1 35.22  -80.84
# 10566  57105    SD    344742581000             6          1 43.52  -96.74
#
#        AVG_DEPOSIT_PER_BRANCH  NORM_DEPOSIT_BASE  NORM_BRANCH_DENSITY  \
# 1523        37,229,562,800.00             739.03                 4.86
# 10569       17,141,570,161.29             527.42                 7.54
# 15861       22,067,241,590.91             481.86                 5.35
# 4361        39,779,685,300.00             394.83                 2.43
# 10566       57,457,096,833.33             342.17                 1.46
#
#        OPPORTUNITY_SCORE  CAPTURE_PCT  EXPECTED_CAPTURE_USD
# 1523              441.47         0.10     74,459,125,600.00
# 10569             313.44         0.10     53,138,867,500.00
# 15861             286.97         0.10     48,547,931,500.00
# 4361              235.92         0.10     39,779,685,300.00
# 10566             204.72         0.10     34,474,258,100.00

# %%
# Plot histogram
fig = px.histogram(
    zip_df,
    x = 'OPPORTUNITY_SCORE',
    nbins = 80, 
    title = 'Distribution of Opportunity Score Across All ZIPs',
    labels = {'OPPORTUNITY_SCORE': 'Opportunity Score'},
    color_discrete_sequence = ['#7C3AED']
)

fig.add_vline(x=0, line_dash='dash', line_color='#EF4444', annotation_text='Score = 0')

fig.update_layout(bargap=0.05, showlegend=False)
fig.show()

# %% [markdown]
# ---
# ## 8. Top Expansion Opportunities

# %%
# Top 20
top20 = zip_df.sort_values('OPPORTUNITY_SCORE', ascending=False).head(20)[
    ['ZIP', 'STATE', 'TOTAL_DEPOSITS','BRANCH_COUNT','OPPORTUNITY_SCORE','CAPTURE_PCT', 'EXPECTED_CAPTURE_USD'
]].copy()

# Format for readability
def format_currency(x):
    return f'${x:,.0f}'

top20['TOTAL_DEPOSITS'] = top20['TOTAL_DEPOSITS'].apply(format_currency)
top20['EXPECTED_CAPTURE_USD'] = top20['EXPECTED_CAPTURE_USD'].apply(format_currency)
top20['CAPTURE_PCT'] = (top20['CAPTURE_PCT']*100).round(1).astype(str) + '%'
top20['OPPORTUNITY_SCORE'] = top20['OPPORTUNITY_SCORE'].round(4)

print('Top 20 ZIPs by Opportunity Score:')
top20
# Out:
# Top 20 ZIPs by Opportunity Score:
#          ZIP STATE    TOTAL_DEPOSITS  BRANCH_COUNT  OPPORTUNITY_SCORE  \
# 1523   10017    NY  $744,591,256,000            20             441.47
# 10569  57108    SD  $531,388,675,000            31             313.44
# 15861  84111    UT  $485,479,315,000            22             286.97
# 4361   28202    NC  $397,796,853,000            10             235.92
# 10566  57105    SD  $344,742,581,000             6             204.72
# 15840  84070    UT  $327,350,994,000            12             193.78
# 3250   19801    DE  $326,004,592,000            16             192.59
# 14542  76262    TX  $241,408,359,000            11             142.69
# 1515   10007    NY  $230,785,413,000            10             136.46
# 1569   10282    NY  $226,112,000,000             1             134.56
# 1641   10577    NY  $212,449,000,000             1             126.42
# 341    02114    MA  $208,846,743,000             6             123.79
# 16999  94104    CA  $211,103,304,000            20             123.77
# 14690  77002    TX  $151,596,964,000            11              89.21
# 11234  60603    IL  $146,350,309,000            12              85.99
# 7597   45202    OH  $136,298,577,000            13              79.90
# 1509   10001    NY  $127,160,315,000            28              73.00
# 14262  75202    TX  $115,457,229,000             3              68.47
# 15815  84020    UT  $113,540,235,000            16              66.06
# 1542   10036    NY  $107,769,037,000            22              62.04
#
#       CAPTURE_PCT EXPECTED_CAPTURE_USD
# 1523        10.0%      $74,459,125,600
# 10569       10.0%      $53,138,867,500
# 15861       10.0%      $48,547,931,500
# 4361        10.0%      $39,779,685,300
# 10566       10.0%      $34,474,258,100
# 15840       10.0%      $32,735,099,400
# 3250        10.0%      $32,600,459,200
# 14542       10.0%      $24,140,835,900
# 1515        10.0%      $23,078,541,300
# 1569        10.0%      $22,611,200,000
# 1641        10.0%      $21,244,900,000
# 341         10.0%      $20,884,674,300
# 16999       10.0%      $21,110,330,400
# 14690       10.0%      $15,159,696,400
# 11234       10.0%      $14,635,030,900
# 7597        10.0%      $13,629,857,700
# 1509        10.0%      $12,716,031,500
# 14262       10.0%      $11,545,722,900
# 15815       10.0%      $11,354,023,500
# 1542        10.0%      $10,776,903,700

# %%
# Scatter: Deposit base vs Branch density, coloured by Opportunity Score

fig = px.scatter(
    zip_df.head(500),
    x = 'NORM_BRANCH_DENSITY',
    y = 'NORM_DEPOSIT_BASE',
    color = 'OPPORTUNITY_SCORE',
    hover_data = ['ZIP','STATE'],
    color_continuous_scale = 'RdYlGn',
    title = 'Top 500 ZIPs: Normalised Deposit Base vs Branch Density',
    labels = {
        'NORM_BRANCH_DENSITY':'Normalised Branch Density',
        'NORM_DEPOSIT_BASE':'Normalised Deposit Base',
        'OPPORTUNITY_SCORE':'Opp. Score'
    }
)

fig.show()
print('Top-left quadrant = high deposits + low density = best expansion targets')
# Out:
# Top-left quadrant = high deposits + low density = best expansion targets

# %% [markdown]
# ---
# ## 9. Year-over-Year Trends (Multi-year only)

# %% [markdown]
# ---
# ## 10. Export Processed Data for Tableau

# %%
# ZIP-level metrics — primary Tableau source
zip_out = OUTPUT_DIR / 'zip_metrics.csv'
zip_df.to_csv(zip_out, index=False)
print(f'Saved:{zip_out} ({len(zip_df):,} rows)')

# State-level summary
state_out = OUTPUT_DIR / 'state_metrics.csv'
state_df.to_csv(state_out, index=False)
print(f'Saved:{state_out} ({len(state_df):,} rows)')

# Branch-level (for geographic detail)
branch_cols = ['CERT','BANK_NAME','ADDRESS','BRNUM','UNINUMBR','STATE','STALP','ZIP','LAT','LON','DEPOSITS_USD','YEAR']
branch_out = OUTPUT_DIR / 'branch_metrics.csv'
df[branch_cols].to_csv(branch_out, index=False)
print(f'Saved:{branch_out} ({len(df):,} rows)')


print('\n All CSVs ready. Connect these CSVs to Tableau Desktop.')
# Out:
# Saved:/Users/Sahil/Documents/Data Analytic Project/Data Analytics Project by Harsh/Project 2 Bank Branch Expansion/data/processed/zip_metrics.csv (17,968 rows)
# Saved:/Users/Sahil/Documents/Data Analytic Project/Data Analytics Project by Harsh/Project 2 Bank Branch Expansion/data/processed/state_metrics.csv (58 rows)
# Saved:/Users/Sahil/Documents/Data Analytic Project/Data Analytics Project by Harsh/Project 2 Bank Branch Expansion/data/processed/branch_metrics.csv (73,868 rows)
#
#  All CSVs ready. Connect these CSVs to Tableau Desktop.
